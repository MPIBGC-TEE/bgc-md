# %% [markdown]
# # How to load a model from a yaml file and apply our toolkit to it
#
# Technical note: There is a jupyter extension called *hide input* that allows to write code and hide it, showing only the output of it. We can use that to write LaTeX code such as
#
# ```
# display(Math("M = " + latex(M)))
# ```
# with $A$ being a sympy matrix. This is a workaround for the problem that in markdown cells
# ```
# $${{latex(M)}}$$
# ```
# is not yet supported.
#
# ## Load the yaml model
#
# In the first step we load `latex` from sympy and `display`, `Math` from `Ipython.display` to make nice notebook outputs. Then we import the yaml model class `Model` from `bgc_md` and initialize a `yaml_model` from a yaml file.

# %%
# imports for IPython
from sympy import latex
from IPython.display import display, Math

# imports for actual model treatment
from bgc_md.Model import Model

yaml_model = Model.from_file("../../bgc_md/data/SoilModels/Andren1997EcologicalApplications.yaml")

# %% [markdown]
# ## Steady state analysis
#
# For an analysis in steady state, we create an LAPM (Linear Autonomous Pool Model) `lin_model` from the `yaml_model`. To that end, we take the `SmoothReservoirModel` that belongs to the `yaml_model` and retrieve its general model decomposition. From $xi, T, A$ we can compute $A$ and then we use $A$ and $u$ to initialize the `lin_model`. We furthermore select one of the model runs with parameter values and initial values specified in the yaml file.

# %%
from LAPM.linear_autonomous_pool_model import LinearAutonomousPoolModel
from sympy import exp
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-2af16c442af9> in <module>()
# ----> 1 from LAPM.LinearAutonomousPoolModel import LinearAutonomousPoolModel
#       2 from sympy import exp
#
# ImportError: No module named 'LAPM.LinearAutonomousPoolModel'

# %%
# get the SmoothReservoirModel from the yaml model
srm = yaml_model.reservoir_model
time_symbol = srm.time_symbol
state_vector = srm.state_vector

# decompose the srm into xi, T, N, C, u
xi, T, N, C, u = srm.xi_T_N_u_representation

# compose A from xi, T, N
A = xi*T*N

# create a LAPM (Linear Autonomous Pool Model) for steady state analyses
lin_model = LinearAutonomousPoolModel(u, A)

# add manually the matrix exponential to the linear model
lin_model.Qt = exp(A*time_symbol)

# select one of the model runs given in the yaml file
smr1 = yaml_model.model_runs[1]
times =smr1.times
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-68eb2a128a3a> in <module>()
# ----> 1 from LAPM.LinearAutonomousPoolModel import LinearAutonomousPoolModel
#       2 from sympy import exp
#       3
#       4 # get the SmoothReservoirModel from the yaml model
#       5 srm = yaml_model.reservoir_model
#
# ImportError: No module named 'LAPM.LinearAutonomousPoolModel'

# %% [markdown]
# We can see that the model has the structure

# %%
display(Math(latex(state_vector) + " = " + latex(A) + latex(state_vector) + " + " + latex(u)))
# Out:
# $$\left[\begin{matrix}Y\\O\end{matrix}\right] = \left[\begin{matrix}- k_{1} r & 0\\h k_{1} r & - k_{2} r\end{matrix}\right]\left[\begin{matrix}Y\\O\end{matrix}\right] + \left[\begin{matrix}i\\0\end{matrix}\right]$$

# %% [markdown]
# As a first analysis, we can look at the symbolic formula for the mean transit time, which is given by

# %%
display(Math("MTT = " + latex(lin_model.T_expected_value)))
# Out:
# $$MTT = \frac{h}{k_{2} r} + \frac{1}{k_{1} r}$$

# %% [markdown]
# The symbolic transit time density equals

# %%
f_T_symbolic = lin_model.T_density()
display(Math("f_T(t) = " + latex(f_T_symbolic) + ","))

f_A_symbolic = lin_model.A_density()
# Out:
# $$f_T(t) = k_{2} r \left(- \frac{h k_{1} e^{- k_{2} r t}}{- k_{1} + k_{2}} + \frac{h k_{1} e^{- k_{1} r t}}{- k_{1} + k_{2}}\right) - \frac{e^{- k_{1} r t}}{r t \left(- k_{1} + k_{2}\right)} \left(- h k_{1} r + k_{1} r\right) \left(k_{1} r t - k_{2} r t\right),$$

# %% [markdown]
# and the symbolic system age density is

# %%
display(Math("f_A(t) = " + latex(f_A_symbolic) + "."))
# Out:
# $$f_A(t) = \frac{h i e^{- k_{2} r y}}{\frac{h i}{k_{2} r} + \frac{i}{k_{1} r}} + \frac{i}{k_{1} r \left(\frac{h i}{k_{2} r} + \frac{i}{k_{1} r}\right)} \left(k_{2} r \left(- \frac{h k_{1} e^{- k_{2} r y}}{- k_{1} + k_{2}} + \frac{h k_{1} e^{- k_{1} r y}}{- k_{1} + k_{2}}\right) - \frac{e^{- k_{1} r y}}{r y \left(- k_{1} + k_{2}\right)} \left(- h k_{1} r + k_{1} r\right) \left(k_{1} r y - k_{2} r y\right)\right).$$

# %% [markdown]
# We use the parameter set
#
# {{smr1.parameter_set}}

# %% [markdown]
# to make a plot of the corresponding transit time and system age densities.
#
# First, we compute the y-values of the densities in the time frame given by the chosen `SmoothModelRun`. There are three ways to do it, either one works. It is important to convert the sympy data type to a numpy float by `astype` for an entire array, `np.float` for a single value, or by creating a vectorized function with `lambdify`.

# %%
import numpy as np

f_T = f_T_symbolic.subs(smr1.parameter_set)
f_A = f_A_symbolic.subs(smr1.parameter_set)

# version 1
values_T = [f_T.subs({'t': t}) for t in times]
values_T = np.array(values_T).astype(np.float)

# version 2
values_T = [np.float(f_T.subs({'t': t}).evalf()) for t in times]

# version 3
from sympy import lambdify
g_T = lambdify([time_symbol], f_T, modules = 'numpy')
values_T = g_T(times)

# we use only version 1 for f_A
values_A = [f_A.subs({'y': t}) for t in times]
values_A = np.array(values_A).astype(np.float)

# %% [markdown]
# We can now finally make the interactive plot with plotly.

# %%
from plotly.offline import init_notebook_mode, iplot
import plotly.graph_objs as go
#init_notebook_mode(connected=True)
#init_notebook_mode(connected=False)
import plotly
plotly.offline.init_notebook_mode()

l_T = go.Scatter(x = times, y = values_T, name = 'f_T', mode = 'lines')
l_A = go.Scatter(x = times, y = values_A, name = 'f_A', mode = 'lines')

iplot([l_T, l_A])
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
# <div id="22b22ab9-9d86-4943-a996-0a7616d81a34" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("22b22ab9-9d86-4943-a996-0a7616d81a34", [{"type": "scatter", "y": [0.7000000000000002, 0.6462395679144846, 0.5966123991122787, 0.550800713232078, 0.508511162027789, 0.46947295093824626, 0.4334361050775121, 0.4001698685421789, 0.3694612267857727, 0.34111354259841264, 0.314945296957337, 0.29078892668544143, 0.2684897514748757, 0.24790498340498632, 0.22890281261213866, 0.21136156325658392, 0.1951689143816769, 0.1802211806762838, 0.1664226485348041, 0.1536849631633236, 0.1419265628072858, 0.13107215647780684, 0.12105224183229964, 0.11180266012219733, 0.10326418535792131, 0.09538214506034806, 0.08810607017028828, 0.0813893718742051, 0.0751890432767511, 0.0694653840098111, 0.06418174601460776, 0.05930429886900768, 0.05480181315732177, 0.05064546049542666, 0.046808628930685534, 0.04326675253459748, 0.03999715409698647, 0.03697889991443601, 0.03419266574311932, 0.03162061305766573, 0.02924627482369761, 0.027054450052591775, 0.025031106463256497, 0.023163290627626246, 0.021439045024499462, 0.019847331470580213, 0.01837796043842101, 0.01702152580866066, 0.01576934463874819, 0.014613401562467626, 0.013546297464230146, 0.012561202099474427, 0.011651810357783647, 0.010812301888653703, 0.010037303831380155, 0.009321856410407349, 0.008661381175833024, 0.00805165168569883, 0.007488766442333502, 0.006969123909448884, 0.006489399450012829, 0.0060465240372227416, 0.00563766460225723, 0.005260205892964421, 0.004911733727320596, 0.004590019534424115, 0.004293006084034193, 0.004018794313274928, 0.0037656311661503575, 0.00353189836800214, 0.0033161020630278395, 0.0031168632485047464, 0.0029329089444654695, 0.0027630640422811542, 0.0026062437799553974, 0.002461446795945065, 0.002327748717028725, 0.002204296239163222, 0.00209030166342557, 0.0019850378520516513, 0.001887833572273045, 0.001798069198136719, 0.0017151727427845165, 0.0016386161957854975, 0.0015679121420675416, 0.0015026106407978576, 0.0014422963442265512, 0.001386585838044028, 0.001335125186221443, 0.001287587664612777, 0.001243671668805874, 0.001203098782825528, 0.0011656119963217386, 0.0011309740588270458, 0.0010989659605445692, 0.0010693855299386188, 0.0010420461391476615, 0.0010167755089298695, 0.0009934146054888186, 0.0009718166221152598, 0.0009518460391239927, 0.0009333777560662231, 0.0009162962906606117, 0.000900495039313422, 0.0008858755944925874, 0.0008723471145845526, 0.0008598257421988215, 0.0008482340671953806, 0.000837500630996529, 0.0008275594690090353, 0.0008183496882265426, 0.0008098150773074487, 0.0008019037466314217, 0.0007945677960296862, 0.0007877630080614193, 0.0007814485648721769, 0.0007755867868212802, 0.000770142891204482, 0.0007650847695269179, 0.0007603827819001246, 0.0007560095672465685, 0.0007519398680963423, 0.0007481503688541325, 0.0007446195465008127, 0.0007413275327736446, 0.0007382559869425678, 0.0007353879783679139, 0.0007327078780875128, 0.0007302012587389776, 0.0007278548021763305, 0.0007256562141893995, 0.0007235941457799007, 0.0007216581204901008, 0.0007198384673187201, 0.0007181262587945038, 0.0007165132538109246, 0.0007149918448559622, 0.0007135550092990496, 0.0007121962644232573, 0.000710909625914767, 0.0007096895695438274, 0.0007085309957918166, 0.0007074291971979063, 0.0007063798282162333, 0.0007053788773905612, 0.000704422641668258, 0.0007035077026891056, 0.0007026309048971146, 0.0007017893353351827, 0.0007009803049932125, 0.0007002013315902546, 0.0006994501236804229, 0.0006987245659808042, 0.0006980227058274132, 0.0006973427406724615, 0.0006966830065428833, 0.0006960419673862117, 0.0006954182052355828, 0.0006948104111308893, 0.0006942173767379513, 0.0006936379866120336, 0.0006930712110561727, 0.0006925160995285823, 0.0006919717745569213, 0.0006914374261204544, 0.00069 ...

# %% [markdown]
# ## Time-dependent analysis
#
# We can just use one of the model runs given in the yaml file and start. To plot the pool ages densities, we define an initial age density (omitting means that initial mass is considered as of age zero which makes of course problems with a smooth plot). Then we compute the age density over an time-age-pool grid and use plotly to plot it.

# %%
# to make the compuation faster we make the time shorter
smr1.times = np.linspace(0,10,101)
times = smr1.times
ages = np.linspace(0,10,101)

# we define some arbitrary start age distribution
def start_age_densities(a):
    return np.exp(-a)*smr1.start_values

# p is a function of an age array to return the pool age density as an array times x ages x pools
p = smr1.age_densities(start_age_densities)
density_data = p(ages)

pool = 0
data = [go.Surface(x = -times, 
                   y = ages, 
                   z = density_data[:,:,pool], 
                   showscale=False)]
layout = go.Layout(
    title = 'Pool ' + state_vector[pool].name
)
fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-98feaf9ba7a5> in <module>()
#       9
#      10 # p is a function of an age array to return the pool age density as an array times x ages x pools
# ---> 11 p = smr1.age_densities(start_age_densities)
#      12 density_data = p(ages)
#      13
#
# TypeError: age_densities() missing 1 required positional argument: 'system_age_density'

# %%
pool = 1
data = [go.Surface(x = -times, 
                   y = ages, 
                   z = density_data[:,:,pool], 
                   showscale=False)]
layout = go.Layout(
    title = 'Pool ' + state_vector[pool].name,
)
fig = go.Figure(data=data, layout=layout)
iplot(fig)

# %% [markdown]
# Unfortunately, plotly does not support reversed axes in 3d plots. This is the reason why I simply negated the time axis. The tick labels would then need to be adapted.
